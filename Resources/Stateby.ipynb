# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
# Read county cancer data

read_file = "incdd.csv"
incd_df = pd.read_csv(read_file, keep_default_na=False, skiprows = 8)
incd_df.dropna(inplace = True)
incd_df.head(20)
# Viz
# Out:
#            Unnamed: 0 Unnamed: 1                            Unnamed: 2  \
# 0               State       FIPS  Met Healthy People Objective of ***?
# 1   US (SEER+NPCR)(1)          0                                   ***
# 2         Kentucky(7)      21000                                   ***
# 3         Delaware(6)      10000                                   ***
# 4       New Jersey(7)      34000                                   ***
# 5         New York(7)      36000                                   ***
# 6     Pennsylvania(6)      42000                                   ***
# 7    New Hampshire(6)      33000                                   ***
# 8        Louisiana(7)      22000                                   ***
# 9             Iowa(7)      19000                                   ***
# 10   West Virginia(6)      54000                                   ***
# 11           Maine(6)      23000                                   ***
# 12    Rhode Island(6)      44000                                   ***
# 13        Arkansas(6)       5000                                   ***
# 14     Connecticut(7)       9000                                   ***
# 15     Mississippi(6)      28000                                   ***
# 16  North Carolina(6)      37000                                   ***
# 17       Minnesota(6)      27000                                   ***
# 18         Georgia(7)      13000                                   ***
# 19        Illinois(6)      17000                                   ***
#
#                                            Unnamed: 3  \
# 0   Age-Adjusted Incidence Rate([rate note]) - cas...
# 1                                               448.7
# 2                                               519.6
# 3                                               488.2
# 4                                               485.9
# 5                                               485.2
# 6                                               484.6
# 7                                               482.4
# 8                                                 481
# 9                                                 479
# 10                                              478.9
# 11                                              474.3
# 12                                              473.6
# 13                                              472.8
# 14                                              470.6
# 15                                              470.6
# 16                                              468.4
# 17                                              467.4
# 18                                                467
# 19                                              465.5
#
#                        Unnamed: 4                     Unnamed: 5  \
# 0   Lower 95% Confidence Interval  Upper 95% Confidence Interval
# 1                           448.4                            449
# 2                           516.8                          522.5
# 3                           482.4                            494
# 4                             484                          487.9
# 5                           483.9                          486.5
# 6                           483.1                          486.2
# 7                           477.6                          487.2
# 8                           478.3                          483.7
# 9                           475.8                          482.2
# 10                          474.9                          482.9
# 11                          469.7                          478.9
# 12                          468.2                            479
# 13                          469.6                          476.1
# 14                          467.7                          473.6
# 15                          467.3                          473.9
# 16                          466.6                          470.2
# 17                            465                          469.8
# 18                          465.1                          468.9
# 19                          463.9                          467.1
#
#               Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# 0   CI*Rank([rank note])  Lower CI (CI*Rank)  Upper CI (CI*Rank)
# 1                   N/A                 N/A                  N/A
# 2                      1                   1                   1
# 3                      2                   2                   8
# 4                      3                   2                   6
# 5                      4                   2                   6
# 6                      5                   2                   7
# 7                      6                   2                  10
# 8                      7                   4                  10
# 9                      8                   5                  11
# 10                     9                   5                  12
# 11                    10                   7                  16
# 12                    11                   7                  18
# 13                    12                   9                  15
# 14                    13                  10                  18
# 15                    14                  10                  18
# 16                    15                  12                  18
# 17                    16                  13                  21
# 18                    17                  13                  21
# 19                    18                  15                  22
#
#               Unnamed: 9   Unnamed: 10  \
# 0   Average Annual Count  Recent Trend
# 1                1673102       falling
# 2                  27313       falling
# 3                   5834       falling
# 4                  51689       falling
# 5                 113149       falling
# 6                  79595       falling
# 7                   8313       falling
# 8                  25360       falling
# 9                  18173       falling
# 10                 11839       falling
# 11                  8817        stable
# 12                  6195        stable
# 13                 16981        stable
# 14                 21014       falling
# 15                 16246       falling
# 16                 55290       falling
# 17                 29787        stable
# 18                 50414       falling
# 19                 68502       falling
#
#                                           Unnamed: 11  \
# 0   Recent 5-Year Trend ([trend note]) in Incidenc...
# 1                                                -1.0
# 2                                                -0.4
# 3                                                -2.8
# 4                                                -0.8
# 5                                                -0.8
# 6                                                -0.9
# 7                                                -0.8
# 8                                                -0.7
# 9                                                -0.2
# 10                                               -0.4
# 11                                               -0.4
# 12                                               -3.0
# 13                                                0.2
# 14                                               -1.3
# 15                                               -0.7
# 16                                               -0.7
# 17                                               -0.3
# 18                                               -0.3
# 19                                               -0.6
#
#                       Unnamed: 12                    Unnamed: 13
# 0   Lower 95% Confidence Interval  Upper 95% Confidence Interval
# 1                            -1.2                           -0.8
# 2                            -0.5                           -0.2
# 3                            -4.6                           -0.8
# 4                            -0.9                           -0.6
# 5                            -1.1                           -0.4
# 6                            -1.4                           -0.5
# 7                            -1.0                           -0.6
# 8                            -0.9                           -0.5
# 9                            -0.3                           -0.1
# 10                           -0.5                           -0.2
# 11                           -1.0                            0.2
# 12                           -6.4                            0.4
# 13                            0.0                            0.4
# 14                           -1.5                           -1.1
# 15                           -1.1                           -0.2
# 16                           -0.9                           -0.4
# 17                           -0.5                            0.0
# 18                           -0.5                           -0.2
# 19                           -0.9                           -0.4

# %%
new_header = incd_df.iloc[0] 
incd_df = incd_df[1:] 
incd_df.columns = new_header
incd3_df = incd_df.reset_index(drop=True)
incd3_df.head()
# Out:
# 0              State   FIPS Met Healthy People Objective of ***?  \
# 0  US (SEER+NPCR)(1)      0                                  ***
# 1        Kentucky(7)  21000                                  ***
# 2        Delaware(6)  10000                                  ***
# 3      New Jersey(7)  34000                                  ***
# 4        New York(7)  36000                                  ***
#
# 0 Age-Adjusted Incidence Rate([rate note]) - cases per 100,000  \
# 0                                              448.7
# 1                                              519.6
# 2                                              488.2
# 3                                              485.9
# 4                                              485.2
#
# 0 Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                         448.4                           449
# 1                         516.8                         522.5
# 2                         482.4                           494
# 3                           484                         487.9
# 4                         483.9                         486.5
#
# 0 CI*Rank([rank note]) Lower CI (CI*Rank) Upper CI (CI*Rank)  \
# 0                 N/A                N/A                 N/A
# 1                    1                  1                  1
# 2                    2                  2                  8
# 3                    3                  2                  6
# 4                    4                  2                  6
#
# 0 Average Annual Count Recent Trend  \
# 0              1673102      falling
# 1                27313      falling
# 2                 5834      falling
# 3                51689      falling
# 4               113149      falling
#
# 0 Recent 5-Year Trend ([trend note]) in Incidence Rates  \
# 0                                               -1.0
# 1                                               -0.4
# 2                                               -2.8
# 3                                               -0.8
# 4                                               -0.8
#
# 0 Lower 95% Confidence Interval Upper 95% Confidence Interval
# 0                          -1.2                          -0.8
# 1                          -0.5                          -0.2
# 2                          -4.6                          -0.8
# 3                          -0.9                          -0.6
# 4                          -1.1                          -0.4

# %%
# Create new df to combine state count totals

chart_df = cancer_stats_df[['State_x','Average Annual Count']]
state_groups_df = chart_df.groupby('State_x')



annual_count = state_groups_df["Average Annual Count"].sum()
annual_count_df = annual_count.to_frame()
annual_count_df = annual_count_df.reset_index(level = None, drop = False, inplace = False, col_level = 0, col_fill = '')
annual_count_df
# Out:
#             State_x                               Average Annual Count
# 0           Alabama  7624144595722561024591273086012725027970815620...
# 1            Alaska  3729418333111524130367486301321431731381764162...
# 2           Arizona  1579165417933148500737664473184586642830117712...
# 3          Arkansas  5911912361170781201441475644712138312445973108...
# 4        California  1253161410134222863274301704162228221021145528...
# 5          Colorado  1110291126282486113979226562524027891491231736...
# 6       Connecticut                     708127810975084164052405173794
# 7          Delaware                                       106730731691
# 8           Florida  2136321667516115063044275811823736113731544792...
# 9           Georgia  2591231625822421971856416822492234137372390550...
# 10           Hawaii                           507383710253493 or fewer
# 11            Idaho  9312293013819712095270852080250762986772480241...
# 12         Illinois  3022122562533027869928211810391659940871315111...
# 13          Indiana  4562142932431583261514561152309071163108424164...
# 14             Iowa  7835277558174153151641261361027277405610112310...
# 15           Kansas  [P1 note][P1 note][P1 note][P1 note][P1 note][...
# 16         Kentucky  9311328819355204100119202833572522238713671601...
# 17        Louisiana  7018421243510182316136319132233620273689514212...
# 18            Maine  1472561004422657134650841030127133677217201962...
# 19         Maryland  6226351546511152428315502410223263194223888152...
# 20    Massachusetts  1326231871901408745444439802784930303178243176...
# 21         Michigan  2391661251029821853201216026810273434291692440...
# 22        Minnesota  [P1 note][P1 note][P1 note][P1 note][P1 note][...
# 23      Mississippi  1119514155195171143139502425716014938565356117...
# 24         Missouri  1959487451664188878166136246155632161971841227...
# 25          Montana  1285776671971962858342844172374151543199595967...
# 26         Nebraska  7282515557133178317672225319223654036268735453...
# 27           Nevada         346323622203413012532388041846528442418617
# 28    New Hampshire                   47519697039472382277288379470565
# 29       New Jersey  8814621853295631234160451189593270621381699303...
# 30       New Mexico  1016146010013932568537398921301823832452331732...
# 31         New York  5281579628398640277698194727463759728293715142...
# 32   North Carolina  1047261146744929265163686382978813132226433553...
# 33     North Dakota  1829375018596817472137571350074124835379421223...
# 34             Ohio  9242318718320744055118229348722118053847325837...
# 35         Oklahoma  5268206415175924222152232464379732841918668198...
# 36           Oregon  1751425823364213743169710645556231314571430142...
# 37     Pennsylvania  1422073235444223822281484344510306408258819192...
# 38     Rhode Island                                  11228473359555311
# 39   South Carolina  2012211134216815992104671675199245323130277826...
# 40     South Dakota  4719372248399851018627162060619320202931147124...
# 41        Tennessee  2331352045524985218185316157198287168574129557...
# 42            Texas  3764013928157467414033411522682429421775430775...
# 43             Utah  3486810196177224109102113639894148123810431998...
# 44          Vermont           4946259400417185359265803138184176271202
# 45         Virginia  2258115269583849761391052226718210212413013683...
# 46       Washington  5201615651468443439901573306794582119831226271...
# 47    West Virginia  1842621706670126596324314753513144673762621031...
# 48        Wisconsin  2323191211209731884918621317120900128103944146...
# 49          Wyoming  3449174186103382425116517067397019612144857948...

# %%
# Create Bar chart showing cancer rate by state

x_axis = np.arange(len(annual_count_df))
ticks = [value for value in x_axis]
# print (list(annual_count_df["State"]))


plt.figure(figsize = (30,10))
plt.bar(x_axis, annual_count_df["Average Annual Count"], color= 'b', alpha =0.75)
plt.xticks(ticks, list(annual_count_df["State_x"]),rotation = 90)
plt.xlabel("States", fontsize = 30)
plt.ylabel("Average Annual Cases", fontsize = 30)
plt.title("Yearly Cancer Cases by States", fontsize = 40)
plt.savefig("./CancerBarChart.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-48670852a1a4> in <module>
#       1 # Create Bar chart showing cancer rate by state
#       2
# ----> 3 x_axis = np.arange(len(annual_count_df))
#       4 ticks = [value for value in x_axis]
#       5 # print (list(annual_count_df["State"]))
#
# NameError: name 'annual_count_df' is not defined
